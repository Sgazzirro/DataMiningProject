# %% [markdown]
# ## Why this notebook
# We wrote a functionality that allows you to have a little look at raw data from MotionSense datasets.  Here you could find some strange behaviours, such the one of subject 5 on "<sitting, trial13>".
# Actors you want to see are randomly selected, so feel free to reload cells whenever you want.
#
# By looking several number of times, we discovered that not all trials have the same length for all subjects, and this could lead us to an imbalanced dataset.

# %%
import sys
sys.path.append("creation_functions")
from creation_functions.looking import have_a_look_at

# %%
ACTIVITY_CODES = ["dws", "jog", "sit", "std", "ups", "wlk"]

TRIAL_CODES = {
    ACTIVITY_CODES[0]:[1,2,11],
    ACTIVITY_CODES[1]:[9,16],
    ACTIVITY_CODES[2]:[5,13],
    ACTIVITY_CODES[3]:[6,14],
    ACTIVITY_CODES[4]:[3,4,12],
    ACTIVITY_CODES[5]:[7,8,15]
}

# %%
dict = {"dws" : [1]}
have_a_look_at(["dws"], dict, "userAcceleration.x")

# %%
dict = {"dws" : [2]}
have_a_look_at(["dws"], dict, "userAcceleration.x")

# %%
dict = {"dws" : [11]}
have_a_look_at(["dws"], dict, "userAcceleration.x")

# %%
dict = {"jog" : [9]}
have_a_look_at(["jog"], dict, "userAcceleration.x")

# %%
dict = {"jog" : [16]}
have_a_look_at(["jog"], dict, "userAcceleration.x")

# %%
dict = {"sit" : [5]}
have_a_look_at(["sit"], dict, "userAcceleration.x")

# %%
dict = {"sit" : [13]}
have_a_look_at(["sit"], dict, "userAcceleration.x")

# %%
dict = {"std" : [6]}
have_a_look_at(["std"], dict, "userAcceleration.x")

# %%
dict = {"std" : [14]}
have_a_look_at(["std"], dict, "userAcceleration.x")

# %%
dict = {"ups" : [3]}
have_a_look_at(["ups"], dict, "userAcceleration.x")

# %%
dict = {"ups" : [4]}
have_a_look_at(["ups"], dict, "userAcceleration.x")

# %%
dict = {"ups" : [12]}
have_a_look_at(["ups"], dict, "userAcceleration.x")

# %%
dict = {"wlk" : [7]}
have_a_look_at(["wlk"], dict, "userAcceleration.x")

# %%
dict = {"wlk" : [8]}
have_a_look_at(["wlk"], dict, "userAcceleration.x")

# %%
dict = {"wlk" : [15]}
have_a_look_at(["wlk"], dict, "userAcceleration.x")
