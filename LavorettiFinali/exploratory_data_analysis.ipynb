# %%
import sys

import pandas as pd

sys.path.append("creation_functions")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from creation_functions.utilities import create_time_series, get_some_filter

# %%
ACTIVITY_CODES = ["dws", "jog", "sit", "std", "ups", "wlk"]

TRIAL_CODES = {
    ACTIVITY_CODES[0]:[1,2,11],
    ACTIVITY_CODES[1]:[9,16],
    ACTIVITY_CODES[2]:[5,13],
    ACTIVITY_CODES[3]:[6,14],
    ACTIVITY_CODES[4]:[3,4,12],
    ACTIVITY_CODES[5]:[7,8,15]
}

ACTORS = np.linspace(1, 24, 24).astype(int)

# %% [markdown]
# ### Step 1: We load the dataset and we take a first look at sample
# In this first phase of pre-processing we want take a look at two datasets:
# - The "raw" _MotionSense_, from which we select a subset of the sensors used in the original experiment; in particular, we dropped the "attitude" and the "gravity" sensor because we have too much different sensors in our phone. So, thinking about comparing the entire work with some personal experiments, we decided to leave them out.
# - The "collapsed" dataaset, which is the version in which each group of samples has been collapsed in a single row during the feature extraction process.
#
# _A Note_: To have a look at how feature extraction has been performed, please open the <NomeNoteBookDoveCiStaLaFeatureExtraction>.

# %%
raw_dataset = create_time_series(mode="raw")

# %%
collapsed_dataset = create_time_series()

# %%
raw_dataset.isna().sum()
# Out:
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# class                 0
# subject               0
# trial                 0
# dtype: int64

# %%
collapsed_dataset.isna().sum()
# Out:
# rotationRate.x_mean        0
# rotationRate.x_std         0
# rotationRate.x_range       0
# rotationRate.x_IRQ         0
# rotationRate.x_kurtosis    0
#                           ..
# userAcceleration.zP#4      0
# userAcceleration.zP#5      0
# class                      0
# subject                    0
# trial                      0
# Length: 99, dtype: int64

# %%
raw_dataset
# Out:
#       rotationRate.x  rotationRate.y  rotationRate.z  userAcceleration.x  \
# 0           0.316738        0.778180        1.082764            0.294894
# 1           0.842032        0.424446        0.643574            0.219405
# 2          -0.138143       -0.040741        0.343563            0.010714
# 3          -0.025005       -1.048717        0.035860           -0.008389
# 4           0.114253       -0.912890        0.047341            0.199441
# ...              ...             ...             ...                 ...
# 2055        1.446270        2.409207       -1.052698            0.034354
# 2056        0.602010        2.675064       -0.472482            0.547953
# 2057        1.125564        4.413143        1.581002            0.910034
# 2058        0.086910        0.436147        1.762577            0.811333
# 2059        0.290219       -2.380552       -0.248128           -0.733485
#
#       userAcceleration.y  userAcceleration.z class  subject  trial
# 0              -0.184493            0.377542   dws        1      1
# 1               0.035846            0.114866   dws        1      1
# 2               0.134701           -0.167808   dws        1      1
# 3               0.136788            0.094958   dws        1      1
# 4               0.353996           -0.044299   dws        1      1
# ...                  ...                 ...   ...      ...    ...
# 2055           -0.574501            0.060144   wlk       24     15
# 2056           -0.481645           -0.232273   wlk       24     15
# 2057            0.194606           -0.770222   wlk       24     15
# 2058            0.424518           -0.716784   wlk       24     15
# 2059            1.490250           -0.275576   wlk       24     15
#
# [1412865 rows x 9 columns]

# %%
collapsed_dataset
# Out:
#     rotationRate.x_mean  rotationRate.x_std  rotationRate.x_range  \
# 0             -0.598261            1.035781              4.233415
# 0             -0.097542            0.911372              4.092728
# 0             -0.487880            0.978326              3.449292
# 0             -0.230015            0.801757              3.117364
# 0             -0.329812            0.915968              3.936913
# ..                  ...                 ...                   ...
# 0              0.167426            0.820002              3.218270
# 0              0.126343            0.864684              3.296552
# 0              0.115019            0.826878              2.920672
# 0              0.173352            1.017701              3.742444
# 0              0.148138            0.878020              3.440233
#
#     rotationRate.x_IRQ  rotationRate.x_kurtosis  rotationRate.x_skewness  \
# 0             1.694033                -0.956685                -0.026229
# 0             1.277495                -0.304429                -0.495648
# 0             1.656486                -1.154190                -0.245725
# 0             1.283280                -1.001235                -0.049592
# 0             1.330359                -0.442254                -0.571874
# ..                 ...                      ...                      ...
# 0             1.132992                -0.277282                -0.712709
# 0             1.340263                -0.396475                -0.779987
# 0             1.411312                -0.870169                -0.638618
# 0             1.614026                -0.978921                -0.555987
# 0             1.376481                -0.429483                -0.817258
#
#     rotationRate.y_mean  rotationRate.y_std  rotationRate.y_range  \
# 0             -0.605087            1.396446              7.230130
# 0             -0.277137            2.013441              9.061658
# 0             -0.365722            1.684748              7.731247
# 0             -0.205252            1.701594              8.058310
# 0             -0.214969            1.872646              8.499392
# ..                  ...                 ...                   ...
# 0              0.100111            1.767713              6.997537
# 0              0.160952            1.712438              6.762558
# 0              0.099231            1.625297              5.384678
# 0              0.086624            1.684937              5.718094
# 0              0.155054            1.683638              6.281771
#
#     rotationRate.y_IRQ  ...  userAcceleration.zX#4  userAcceleration.zX#5  \
# 0             1.424294  ...               0.001733               0.002000
# 0             2.576537  ...               0.002133               0.002533
# 0             1.979464  ...               0.001867               0.002267
# 0             1.863078  ...               0.001333               0.001600
# 0             1.856482  ...               0.001600               0.001867
# ..                 ...  ...                    ...                    ...
# 0             3.079349  ...               0.001467               0.001867
# 0             2.952453  ...               0.001467               0.001867
# 0             2.896010  ...               0.001467               0.001867
# 0             2.846144  ...               0.001467               0.001867
# 0             3.204978  ...               0.001467               0.001867
#
#     userAcceleration.zP#1  userAcceleration.zP#2  userAcceleration.zP#3  \
# 0               13.700572              10.224221              10.358839
# 0                5.850030              11.432027               6.780674
# 0                4.412037              13.431157               9.487825
# 0                5.226085               5.735624               9.180742
# 0                6.868747              20.724819               3.935775
# ..                    ...                    ...                    ...
# 0                8.432027              23.248258              16.387223
# 0                2.744796              28.087900              19.125783
# 0                4.545763              23.301324              14.934430
# 0                8.853651              22.491873              10.427867
# 0                6.513359              25.686275              15.784124
#
#     userAcceleration.zP#4  userAcceleration.zP#5  class  subject  trial
# 0                6.709421               4.084380    dws        1      1
# 0                2.345534               3.073217    dws        1      1
# 0                6.022618               2.581206    dws        1      1
# 0                3.292413               3.253893    dws        1      1
# 0                6.981037               4.640950    dws        1      1
# ..                    ...                    ...    ...      ...    ...
# 0               17.326343              14.355209    wlk       24     15
# 0               22.283682              15.586845    wlk       24     15
# 0               15.267009              13.367485    wlk       24     15
# 0               15.859912              12.952285    wlk       24     15
# 0               19.508589              15.225755    wlk       24     15
#
# [8882 rows x 99 columns]

# %%
raw_dataset.to_csv("raw_dataset.csv")
collapsed_dataset.to_csv("collapsed_dataset.csv")

# %%
raw_dataset = pd.read_csv("raw_dataset.csv", index_col=0)
collapsed_dataset = pd.read_csv("collapsed_dataset.csv", index_col=0)

# %%
fig, axes = plt.subplots(2, 1, figsize=(8,8))
plt.subplots_adjust(hspace = 0.5)
sns.countplot(x="class",data=raw_dataset, ax=axes[0]).set(title="Class Distribution (Raw Data)")
sns.countplot(x="class", data=collapsed_dataset, ax=axes[1]).set(title="Class Distribution (Collapsed Data)")
# Out:
# [Text(0.5, 1.0, 'Class Distribution (Collapsed Data)')]

# %%
# Have a look a some signals for sitting
ACTIVITY_CODES_s = ["sit"]
TRIAL_CODES_s = { ACTIVITY_CODES_s[0]:[13]}
sitting_subjects = get_some_filter(raw_dataset,[5, 6, 7, 8, 9, 10], ["sit"])
sitting_subjects = sitting_subjects.loc[sitting_subjects["trial"] == 13]

# %%
# Trials seem to have different duration
sns.countplot(x="subject", data=sitting_subjects)
plt.title("Different lenght of Trial 13 (Sitting) for some subjects")
# Out:
# Text(0.5, 1.0, 'Different lenght of Trial 13 (Sitting) for some subjects')

# %%
collapsed_dataset["subject"].value_counts().sort_index()
# Out:
# 1     392
# 2     395
# 3     395
# 4     352
# 5     327
# 6     361
# 7     386
# 8     383
# 9     359
# 10    375
# 11    372
# 12    332
# 13    320
# 14    355
# 15    372
# 16    415
# 17    347
# 18    397
# 19    457
# 20    346
# 21    436
# 22    349
# 23    342
# 24    317
# Name: subject, dtype: int64

# %%
fig, axes = plt.subplots(2, 3, sharex=True)
index = 0
fig.text(0.5, 0.04, 'Subjects', ha='center')
fig.text(0.04, 0.5, 'Cumulative Sum of the Class', va='center', rotation='vertical')
for act in ACTIVITY_CODES:
    length_act = get_some_filter(collapsed_dataset, ACTORS, [act])["subject"].value_counts().sort_index()
    axes[int(index/3)][index%3].plot(np.cumsum(length_act))
    axes[int(index/3)][index%3].set_title(str(act))
    index += 1

# %%
labels = ["subject 5", "subject 6", "subject 7", "subject 8", "subject 9", "subject 10"]
for i in [5, 6, 7, 8, 9, 10]:
    plt.plot(sitting_subjects.loc[sitting_subjects["subject"] == i]["userAcceleration.x"])
plt.legend(labels)
plt.suptitle("Comparison sitting activity between different subjects, userAcceleration.x")
# Out:
# Text(0.5, 0.98, 'Comparison sitting activity between different subjects, userAcceleration.x')

# %%
labels = ["subject 5", "subject 6", "subject 7", "subject 8", "subject 9", "subject 10"]
for i in [5, 6, 7, 8, 9, 10]:
    plt.plot(sitting_subjects.loc[sitting_subjects["subject"] == i]["userAcceleration.y"])
plt.legend(labels)
plt.suptitle("Comparison sitting activity between different subjects, userAcceleration.y")
# Out:
# Text(0.5, 0.98, 'Comparison sitting activity between different subjects, userAcceleration.y')

# %%
labels = ["subject 5", "subject 6", "subject 7", "subject 8", "subject 9", "subject 10"]
for i in [5, 6, 7, 8, 9, 10]:
    plt.plot(sitting_subjects.loc[sitting_subjects["subject"] == i]["userAcceleration.z"])
plt.legend(labels)
plt.suptitle("Comparison sitting activity between different subjects, userAcceleration.z")

# %% [markdown]
# #### What do we learn from this exploratory data analysis:
# - First, both raw dataset and collapsed dataset (with aggregated features) doesn't have any NaN value
# - Secondly, we noticed that the class distribution is a bit unbalanced, with (for example), "jogging" having < 50% of walking class. We have seen that trials have different length, and so It has been this fact that lead the dataset to be unbalanced.
# - Thirdly, we wanted to know if some actors contributed differently between each other in class counting, but the plotting of the cumulative sum varying subjects proves that each subject contributed more or less equally in that. That's a good news, looking for a custom cross validation that involves the division in subjects instead of the entire dataset.
#
# Moreover, we tested methods in the notebook _"raw_data_visualization"_ and we discovered that **subject 5** had a really strange behaviur during trial 13 (sitting).

# %% [markdown]
# ### Step 2: Data Cleaning
# We already stated that there's no NaN value, so in this phase we want to determine:
# - What type of smoothing, if necessary, we should use
# - _Dimensionality Reduction_ : we want to state if some attributes are "too much" correlated, and so try to understand if we chan chop out some of them.
#
# _A note_: We decided to perform the task of having a sight on correlation *before* feature extraction. In this manner, we expect to have better results later.

# %%
from scipy.signal import savgol_filter

# Here we have a template for the real function we are putting in .py file
def noise_filter(data, k=10, pol=2):
    dataframe = data.copy()
    for column in dataframe.columns:
        dataframe[column] = savgol_filter(dataframe[column], k, pol, axis=0)
    return dataframe

# %%
little_test = get_some_filter(raw_dataset, [5], ["jog"])
little_test = little_test.loc[little_test["trial"] == 9][100:250]
little_test.drop(["subject", "trial", "class"], axis=1, inplace=True)

# %%
f, axes=plt.subplots(2,2,figsize=(20,10))
f.suptitle("Comparison between different smoothing parameters", fontsize=25)

axes[0][0].plot(little_test["userAcceleration.x"])
axes[0][0].plot(noise_filter(little_test)["userAcceleration.x"])
axes[0][0].legend(["Original", "Smooth with K=10 and PolyOrder=2"])

axes[0][1].plot(little_test["userAcceleration.x"])
axes[0][1].plot(noise_filter(little_test, k=5, pol=2)["userAcceleration.x"])
axes[0][1].legend(["Original", "Smooth with K=5 and PolyOrder=2"])

axes[1][0].plot(little_test["userAcceleration.x"])
axes[1][0].plot(noise_filter(little_test, k=5, pol=4)["userAcceleration.x"])
axes[1][0].legend(["Original", "Smooth with K=5 and PolyOrder=4"])

axes[1][1].plot(little_test["userAcceleration.x"])
axes[1][1].plot(noise_filter(little_test, k=10, pol=4)["userAcceleration.x"])
axes[1][1].legend(["Original", "Smooth with K=10 and PolyOrder=4"])

# %% [markdown]
# We chose to filter K = 5 and PolyOrder = 2, to have a not so high smooth ratio and preserve qualitatively the true height of peaks

# %% [markdown]
# Before continuing, we decided to drop trial 13 (sitting) of subject 5 because, as we have seen above, it has some errors inside

# %%
new_dataset = collapsed_dataset.loc[(collapsed_dataset["subject"] != 5) | (collapsed_dataset["trial"] != 13)]

# %%
new_dataset.loc[new_dataset["subject"] == 5]
# Out:
#     rotationRate.x_mean  rotationRate.x_std  rotationRate.x_range  \
# 0             -0.137866            0.709238              4.170011
# 0             -0.014718            0.907023              3.688603
# 0              0.008584            1.042698              4.113037
# 0              0.041000            1.021797              3.711143
# 0              0.034461            1.104193              4.382362
# ..                  ...                 ...                   ...
# 0             -0.006455            1.464124              5.691386
# 0              0.177189            1.490695              5.724970
# 0              0.042237            1.407194              5.429759
# 0             -0.072148            1.516799              5.428942
# 0              0.016485            1.414720              5.446216
#
#     rotationRate.x_IRQ  rotationRate.x_kurtosis  rotationRate.x_skewness  \
# 0             0.508285                 2.293901                 0.164707
# 0             1.064154                -0.334808                -0.391461
# 0             1.332971                -0.775803                -0.189438
# 0             1.455820                -0.934639                -0.276054
# 0             1.694797                -0.852360                 0.066776
# ..                 ...                      ...                      ...
# 0             2.097176                -0.749698                 0.007470
# 0             2.329973                -0.824487                -0.291422
# 0             2.025235                -0.749974                -0.228545
# 0             2.177371                -0.983401                -0.092459
# 0             1.833088                -0.630206                -0.225446
#
#     rotationRate.y_mean  rotationRate.y_std  rotationRate.y_range  \
# 0             -0.115893            0.649593              2.784240
# 0             -0.113267            0.581275              2.812856
# 0             -0.699498            0.919775              4.370275
# 0             -0.253059            0.570803              2.725302
# 0             -0.586090            0.860200              4.474897
# ..                  ...                 ...                   ...
# 0             -0.108483            1.437155              5.704380
# 0              0.162702            1.307059              5.173466
# 0              0.060360            1.400185              4.971153
# 0             -0.121882            1.378495              5.573874
# 0             -0.002744            1.293560              5.463450
#
#     rotationRate.y_IRQ  ...  userAcceleration.zX#4  userAcceleration.zX#5  \
# 0             0.782411  ...               0.001333               0.001600
# 0             0.568852  ...               0.001733               0.002133
# 0             1.308276  ...               0.002000               0.002267
# 0             0.807254  ...               0.001867               0.002667
# 0             0.906911  ...               0.001600               0.002133
# ..                 ...  ...                    ...                    ...
# 0             2.434146  ...               0.001600               0.002267
# 0             2.135547  ...               0.001600               0.001867
# 0             2.381372  ...               0.002000               0.002267
# 0             2.276147  ...               0.001600               0.001867
# 0             2.134055  ...               0.002000               0.002400
#
#     userAcceleration.zP#1  userAcceleration.zP#2  userAcceleration.zP#3  \
# 0                2.973959               2.609885               1.140648
# 0                8.141744               6.155935               4.034259
# 0                7.675931               6.691527               5.282807
# 0                4.048538               8.286239               3.412911
# 0                2.981105               5.478874               8.869441
# ..                    ...                    ...                    ...
# 0                1.570580              16.036435              11.269342
# 0                4.262181              13.387700              11.205325
# 0               14.271928               7.616847              15.262354
# 0                3.403267              13.310555               6.601048
# 0               14.292693               9.590965              13.753854
#
#     userAcceleration.zP#4  userAcceleration.zP#5  class  subject  trial
# 0                1.566671               2.589593    dws        5      1
# 0                2.432669               2.963106    dws        5      1
# 0                3.470323               1.948260    dws        5      1
# 0                3.160138               1.464539    dws        5      1
# 0                5.368069               2.266466    dws        5      1
# ..                    ...                    ...    ...      ...    ...
# 0               12.561636               2.015275    wlk        5     15
# 0               12.569839               0.886111    wlk        5     15
# 0                2.281773               1.971937    wlk        5     15
# 0               11.856713               2.505850    wlk        5     15
# 0                2.075158               1.616075    wlk        5     15
#
# [300 rows x 99 columns]

# %%
only_numeric_dataset = new_dataset.drop(["trial", "subject"], axis=1)
only_numeric_dataset.corr()
# Out:
#                          rotationRate.x_mean  rotationRate.x_std  \
# rotationRate.x_mean                 1.000000            0.073366
# rotationRate.x_std                  0.073366            1.000000
# rotationRate.x_range                0.063317            0.990217
# rotationRate.x_IRQ                  0.103397            0.978254
# rotationRate.x_kurtosis            -0.047524           -0.467745
# ...                                      ...                 ...
# userAcceleration.zP#1               0.092855            0.777028
# userAcceleration.zP#2               0.063029            0.831253
# userAcceleration.zP#3               0.047334            0.802949
# userAcceleration.zP#4               0.073792            0.789455
# userAcceleration.zP#5               0.065599            0.751379
#
#                          rotationRate.x_range  rotationRate.x_IRQ  \
# rotationRate.x_mean                  0.063317            0.103397
# rotationRate.x_std                   0.990217            0.978254
# rotationRate.x_range                 1.000000            0.950340
# rotationRate.x_IRQ                   0.950340            1.000000
# rotationRate.x_kurtosis             -0.453060           -0.469375
# ...                                       ...                 ...
# userAcceleration.zP#1                0.759165            0.795287
# userAcceleration.zP#2                0.820433            0.830783
# userAcceleration.zP#3                0.791520            0.805846
# userAcceleration.zP#4                0.775651            0.795626
# userAcceleration.zP#5                0.749115            0.740138
#
#                          rotationRate.x_kurtosis  rotationRate.x_skewness  \
# rotationRate.x_mean                    -0.047524                -0.016931
# rotationRate.x_std                     -0.467745                 0.148755
# rotationRate.x_range                   -0.453060                 0.153379
# rotationRate.x_IRQ                     -0.469375                 0.119894
# rotationRate.x_kurtosis                 1.000000                -0.114235
# ...                                          ...                      ...
# userAcceleration.zP#1                  -0.336611                 0.073548
# userAcceleration.zP#2                  -0.408331                 0.130073
# userAcceleration.zP#3                  -0.379532                 0.113739
# userAcceleration.zP#4                  -0.383883                 0.129363
# userAcceleration.zP#5                  -0.346501                 0.122825
#
#                          rotationRate.y_mean  rotationRate.y_std  \
# rotationRate.x_mean                 0.013088            0.080008
# rotationRate.x_std                  0.077442            0.901503
# rotationRate.x_range                0.053623            0.905756
# rotationRate.x_IRQ                  0.090828            0.874799
# rotationRate.x_kurtosis            -0.042787           -0.448351
# ...                                      ...                 ...
# userAcceleration.zP#1               0.061999            0.766816
# userAcceleration.zP#2               0.039072            0.830800
# userAcceleration.zP#3               0.028999            0.818969
# userAcceleration.zP#4               0.015711            0.791163
# userAcceleration.zP#5               0.020093            0.737954
#
#                          rotationRate.y_range  rotationRate.y_IRQ  ...  \
# rotationRate.x_mean                  0.077446            0.084874  ...
# rotationRate.x_std                   0.899889            0.866915  ...
# rotationRate.x_range                 0.910673            0.866370  ...
# rotationRate.x_IRQ                   0.867915            0.845986  ...
# rotationRate.x_kurtosis             -0.439273           -0.440155  ...
# ...                                       ...                 ...  ...
# userAcceleration.zP#1                0.751916            0.766726  ...
# userAcceleration.zP#2                0.818210            0.810695  ...
# userAcceleration.zP#3                0.805698            0.803602  ...
# userAcceleration.zP#4                0.772493            0.788326  ...
# userAcceleration.zP#5                0.732794            0.723827  ...
#
#                          userAcceleration.zX#1  userAcceleration.zX#2  \
# rotationRate.x_mean                   0.005802               0.006163
# rotationRate.x_std                   -0.100565              -0.140538
# rotationRate.x_range                 -0.096194              -0.138347
# rotationRate.x_IRQ                   -0.101996              -0.139843
# rotationRate.x_kurtosis               0.114304               0.160077
# ...                                        ...                    ...
# userAcceleration.zP#1                 0.070960               0.068225
# userAcceleration.zP#2                -0.155634              -0.184489
# userAcceleration.zP#3                -0.088622              -0.121040
# userAcceleration.zP#4                -0.141368              -0.175920
# userAcceleration.zP#5                -0.132959              -0.191432
#
#                          userAcceleration.zX#3  userAcceleration.zX#4  \
# rotationRate.x_mean                   0.016516               0.013738
# rotationRate.x_std                   -0.136935              -0.139490
# rotationRate.x_range                 -0.134730              -0.137631
# rotationRate.x_IRQ                   -0.136954              -0.138096
# rotationRate.x_kurtosis               0.183419               0.189413
# ...                                        ...                    ...
# userAcceleration.zP#1                 0.058739               0.050916
# userAcceleration.zP#2                -0.167758              -0.177045
# userAcceleration.zP#3                -0.109487              -0.093712
# userAcceleration.zP#4                -0.191595              -0.185959
# userAcceleration.zP#5                -0.205878              -0.224059
#
#                          userAcceleration.zX#5  userAcceleration.zP#1  \
# rotationRate.x_mean                   0.019002               0.092855
# rotationRate.x_std                   -0.144714               0.777028
# rotationRate.x_range                 -0.144384               0.759165
# rotationRate.x_IRQ                   -0.141014               0.795287
# rotationRate.x_kurtosis               0.189528              -0.336611
# ...                                        ...                    ...
# userAcceleration.zP#1                 0.025268               1.000000
# userAcceleration.zP#2                -0.170423               0.640744
# userAcceleration.zP#3                -0.101974               0.785725
# userAcceleration.zP#4                -0.167227               0.698634
# userAcceleration.zP#5                -0.221124               0.627936
#
#                          userAcceleration.zP#2  userAcceleration.zP#3  \
# rotationRate.x_mean                   0.063029               0.047334
# rotationRate.x_std                    0.831253               0.802949
# rotationRate.x_range                  0.820433               0.791520
# rotationRate.x_IRQ                    0.830783               0.805846
# rotationRate.x_kurtosis              -0.408331              -0.379532
# ...                                        ...                    ...
# userAcceleration.zP#1                 0.640744               0.785725
# userAcceleration.zP#2                 1.000000               0.808671
# userAcceleration.zP#3                 0.808671               1.000000
# userAcceleration.zP#4                 0.833928               0.790939
# userAcceleration.zP#5                 0.744442               0.697088
#
#                          userAcceleration.zP#4  userAcceleration.zP#5
# rotationRate.x_mean                   0.073792               0.065599
# rotationRate.x_std                    0.789455               0.751379
# rotationRate.x_range                  0.775651               0.749115
# rotationRate.x_IRQ                    0.795626               0.740138
# rotationRate.x_kurtosis              -0.383883              -0.346501
# ...                                        ...                    ...
# userAcceleration.zP#1                 0.698634               0.627936
# userAcceleration.zP#2                 0.833928               0.744442
# userAcceleration.zP#3                 0.790939               0.697088
# userAcceleration.zP#4                 1.000000               0.765721
# userAcceleration.zP#5                 0.765721               1.000000
#
# [96 rows x 96 columns]

# %%
# Create correlation matrix
corr_matrix = only_numeric_dataset.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
# Drop features
to_drop
# Out:
# ['rotationRate.x_range',
#  'rotationRate.x_IRQ',
#  'rotationRate.y_range',
#  'rotationRate.y_IRQ',
#  'rotationRate.z_range',
#  'rotationRate.z_IRQ',
#  'userAcceleration.x_range',
#  'userAcceleration.x_IRQ',
#  'userAcceleration.y_range',
#  'userAcceleration.y_IRQ',
#  'userAcceleration.z_range',
#  'userAcceleration.z_IRQ',
#  'rotationRate.xP#1']

# %%
only_numeric_dataset_filtered = only_numeric_dataset.drop(to_drop, axis=1)

# %% [markdown]
# For seeing how much important it has been to remove highly correlated features, let's perform a primitive feature selection, let's say a SelectKBeast(k=4), and have a look at the feature selected

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import LabelEncoder
# Out:
#     rotationRate.x_mean  rotationRate.x_std  rotationRate.x_range  \
# 0             -0.598261            1.035781              4.233415
# 0             -0.097542            0.911372              4.092728
# 0             -0.487880            0.978326              3.449292
# 0             -0.230015            0.801757              3.117364
# 0             -0.329812            0.915968              3.936913
# ..                  ...                 ...                   ...
# 0              0.167426            0.820002              3.218270
# 0              0.126343            0.864684              3.296552
# 0              0.115019            0.826878              2.920672
# 0              0.173352            1.017701              3.742444
# 0              0.148138            0.878020              3.440233
#
#     rotationRate.x_IRQ  rotationRate.x_kurtosis  rotationRate.x_skewness  \
# 0             1.694033                -0.956685                -0.026229
# 0             1.277495                -0.304429                -0.495648
# 0             1.656486                -1.154190                -0.245725
# 0             1.283280                -1.001235                -0.049592
# 0             1.330359                -0.442254                -0.571874
# ..                 ...                      ...                      ...
# 0             1.132992                -0.277282                -0.712709
# 0             1.340263                -0.396475                -0.779987
# 0             1.411312                -0.870169                -0.638618
# 0             1.614026                -0.978921                -0.555987
# 0             1.376481                -0.429483                -0.817258
#
#     rotationRate.y_mean  rotationRate.y_std  rotationRate.y_range  \
# 0             -0.605087            1.396446              7.230130
# 0             -0.277137            2.013441              9.061658
# 0             -0.365722            1.684748              7.731247
# 0             -0.205252            1.701594              8.058310
# 0             -0.214969            1.872646              8.499392
# ..                  ...                 ...                   ...
# 0              0.100111            1.767713              6.997537
# 0              0.160952            1.712438              6.762558
# 0              0.099231            1.625297              5.384678
# 0              0.086624            1.684937              5.718094
# 0              0.155054            1.683638              6.281771
#
#     rotationRate.y_IRQ  ...  userAcceleration.zX#2  userAcceleration.zX#3  \
# 0             1.424294  ...               0.000933               0.001200
# 0             2.576537  ...               0.001067               0.001733
# 0             1.979464  ...               0.000933               0.001333
# 0             1.863078  ...               0.000533               0.000800
# 0             1.856482  ...               0.001067               0.001333
# ..                 ...  ...                    ...                    ...
# 0             3.079349  ...               0.000667               0.001067
# 0             2.952453  ...               0.000667               0.001067
# 0             2.896010  ...               0.000667               0.001067
# 0             2.846144  ...               0.000667               0.001067
# 0             3.204978  ...               0.000667               0.001067
#
#     userAcceleration.zX#4  userAcceleration.zX#5  userAcceleration.zP#1  \
# 0                0.001733               0.002000              13.700572
# 0                0.002133               0.002533               5.850030
# 0                0.001867               0.002267               4.412037
# 0                0.001333               0.001600               5.226085
# 0                0.001600               0.001867               6.868747
# ..                    ...                    ...                    ...
# 0                0.001467               0.001867               8.432027
# 0                0.001467               0.001867               2.744796
# 0                0.001467               0.001867               4.545763
# 0                0.001467               0.001867               8.853651
# 0                0.001467               0.001867               6.513359
#
#     userAcceleration.zP#2  userAcceleration.zP#3  userAcceleration.zP#4  \
# 0               10.224221              10.358839               6.709421
# 0               11.432027               6.780674               2.345534
# 0               13.431157               9.487825               6.022618
# 0                5.735624               9.180742               3.292413
# 0               20.724819               3.935775               6.981037
# ..                    ...                    ...                    ...
# 0               23.248258              16.387223              17.326343
# 0               28.087900              19.125783              22.283682
# 0               23.301324              14.934430              15.267009
# 0               22.491873              10.427867              15.859912
# 0               25.686275              15.784124              19.508589
#
#     userAcceleration.zP#5  class
# 0                4.084380    dws
# 0                3.073217    dws
# 0                2.581206    dws
# 0                3.253893    dws
# 0                4.640950    dws
# ..                    ...    ...
# 0               14.355209    wlk
# 0               15.586845    wlk
# 0               13.367485    wlk
# 0               12.952285    wlk
# 0               15.225755    wlk
#
# [8855 rows x 97 columns]

# %%
encoder=LabelEncoder()
feature_sel = SelectKBest(k=4).fit(only_numeric_dataset.drop("class", axis=1), encoder.fit_transform(only_numeric_dataset["class"]))
selected_features=feature_sel.get_support(indices=True)
selected_features=np.append(selected_features, 96)

test1 =only_numeric_dataset.iloc[:, selected_features]

sns.pairplot(data=test1.sample(n=200), hue="class").set(title="Pair plot of 4 best features")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 encoder=LabelEncoder()
#       2 feature_sel = SelectKBest(k=4).fit(only_numeric_dataset.drop("class", axis=1), encoder.fit_transform(only_numeric_dataset["class"]))
#       3 selected_features=feature_sel.get_support(indices=True)
#
# NameError: name 'LabelEncoder' is not defined

# %% [markdown]
# We can easily notice that userAccelaration.y_std, userAcceleration.y_range, userAcceleration.y_IRQ seem to be highly correlated at a first sight.

# %%
encoder=LabelEncoder()
feature_sel = SelectKBest(k=4).fit(only_numeric_dataset_filtered.drop("class", axis=1), encoder.fit_transform(only_numeric_dataset_filtered["class"]))
selected_features=feature_sel.get_support(indices=True)
selected_features=np.append(selected_features, 83)

test1 =only_numeric_dataset_filtered.iloc[:, selected_features]

sns.pairplot(data=test1.sample(n=200), hue="class").set(title="Pair plot of 4 best features after removing correlated ones")

# %% [markdown]
# As we can see, features appear to be more sparse now, and SelectKBest choose more different features.

# %%
# Check for duplicates
print(only_numeric_dataset_filtered.shape)
only_numeric_dataset_filtered.duplicated(keep=False)
print(only_numeric_dataset_filtered.shape)
# Out:
# (8855, 84)
# (8855, 84)

# %%
only_numeric_dataset_filtered.duplicated()
# Out:
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
#      ...
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# Length: 8855, dtype: bool

# %% [markdown]
# ### Preprocessing ends here
# We have learned a bit of information from data in this second phase. In particular:
# - We identified there are some feature extracted that are too similar with others. SelectKBest, a feature selector that doesn't care by default at redudancy, select different features it they are first filtered using a correlation index (we used a correlation threshold of 95%)
# - We choosed the number of points of smoothing and the degree of the smoothing function as K = 5 and PolOrder = 2.
# - We checked for duplicated after all preprocessing steps.
